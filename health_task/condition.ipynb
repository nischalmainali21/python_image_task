# %%
import pandas as pd
import glob

# %%
file_paths = glob.glob(f"./health_data/healthcare-datasets/*.json")
dfs = [pd.read_json(file_path) for file_path in file_paths]
combined_df = pd.concat(dfs, ignore_index=True)
entries = pd.json_normalize(combined_df['entry'])

# %%
entries['resource.resourceType'].unique()
# Out:
# array(['Patient', 'Encounter', 'Condition', 'Observation',
#        'MedicationRequest', 'Immunization', 'Procedure', 'CarePlan',
#        'AllergyIntolerance', 'DiagnosticReport'], dtype=object)

# %%
condition_data = entries[entries['resource.resourceType'] == 'Condition']
condition_data.reset_index(drop=True,inplace=True)
condition_data.head()
# Out:
#                                          fullUrl  \
# 0  urn:uuid:dff431d5-79b9-40c0-91b6-e3032cf93a20
# 1  urn:uuid:be9865e1-76d5-4e23-b94d-7e3da3c0e762
# 2  urn:uuid:3f257d68-ea56-42b5-b926-74165e287c62
# 3  urn:uuid:bda57d2c-732a-4f5b-a0bc-f9b49ca45cb0
# 4  urn:uuid:41b412e2-fc7f-4f0d-8a31-cf793c1426e5
#
#                             resource.id resource.text.status  \
# 0  dff431d5-79b9-40c0-91b6-e3032cf93a20                  NaN
# 1  be9865e1-76d5-4e23-b94d-7e3da3c0e762                  NaN
# 2  3f257d68-ea56-42b5-b926-74165e287c62                  NaN
# 3  bda57d2c-732a-4f5b-a0bc-f9b49ca45cb0                  NaN
# 4  41b412e2-fc7f-4f0d-8a31-cf793c1426e5                  NaN
#
#   resource.text.div resource.extension resource.identifier resource.name  \
# 0               NaN                NaN                 NaN           NaN
# 1               NaN                NaN                 NaN           NaN
# 2               NaN                NaN                 NaN           NaN
# 3               NaN                NaN                 NaN           NaN
# 4               NaN                NaN                 NaN           NaN
#
#   resource.telecom resource.gender resource.birthDate  ...  \
# 0              NaN             NaN                NaN  ...
# 1              NaN             NaN                NaN  ...
# 2              NaN             NaN                NaN  ...
# 3              NaN             NaN                NaN  ...
# 4              NaN             NaN                NaN  ...
#
#   resource.deceasedDateTime resource.valueCodeableConcept.coding  \
# 0                       NaN                                  NaN
# 1                       NaN                                  NaN
# 2                       NaN                                  NaN
# 3                       NaN                                  NaN
# 4                       NaN                                  NaN
#
#   resource.dispenseRequest.numberOfRepeatsAllowed  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   resource.dispenseRequest.quantity.value  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   resource.dispenseRequest.quantity.unit  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   resource.dispenseRequest.expectedSupplyDuration.value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   resource.dispenseRequest.expectedSupplyDuration.unit  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   resource.dispenseRequest.expectedSupplyDuration.system  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   resource.dispenseRequest.expectedSupplyDuration.code  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   resource.multipleBirthInteger
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 68 columns]

# %%
condition_id = condition_data['resource.id']
condition_id
# Out:
# 0      dff431d5-79b9-40c0-91b6-e3032cf93a20
# 1      be9865e1-76d5-4e23-b94d-7e3da3c0e762
# 2      3f257d68-ea56-42b5-b926-74165e287c62
# 3      bda57d2c-732a-4f5b-a0bc-f9b49ca45cb0
# 4      41b412e2-fc7f-4f0d-8a31-cf793c1426e5
#                        ...
# 146    ff5133e8-6d61-46f4-aa79-446533960eac
# 147    e827d0e4-a1d9-49e3-9edf-038319e25ed3
# 148    fa532314-d31b-461c-b216-d24c99c6d27c
# 149    c3652015-baae-41ca-b044-84c2d9e252df
# 150    3a043586-6429-49e3-8bea-1db4ba5caed9
# Name: resource.id, Length: 151, dtype: object

# %%
condition_clinical_status = condition_data.get('resource.clinicalStatus',None)
condition_clinical_status
# Out:
# 0      active
# 1      active
# 2      active
# 3      active
# 4      active
#         ...
# 146    active
# 147    active
# 148    active
# 149    active
# 150    active
# Name: resource.clinicalStatus, Length: 151, dtype: object

# %%
condition_verification_status = condition_data.get('resource.verificationStatus',None)
condition_verification_status
# Out:
# 0      confirmed
# 1      confirmed
# 2      confirmed
# 3      confirmed
# 4      confirmed
#          ...
# 146    confirmed
# 147    confirmed
# 148    confirmed
# 149    confirmed
# 150    confirmed
# Name: resource.verificationStatus, Length: 151, dtype: object

# %%
condition_name_raw = condition_data.get('resource.code.coding',None)
if not condition_name_raw is None:
    condition_name = pd.json_normalize(condition_name_raw.explode()).get('display',None)
else:
    condition_name = None
condition_name
# Out:
# 0       Streptococcal sore throat (disorder)
# 1         Acute viral pharyngitis (disorder)
# 2                 Viral sinusitis (disorder)
# 3                Acute bronchitis (disorder)
# 4                           Normal pregnancy
#                        ...
# 146                             Hypertension
# 147    Concussion with loss of consciousness
# 148               Viral sinusitis (disorder)
# 149                      Fracture of forearm
# 150               Viral sinusitis (disorder)
# Name: display, Length: 151, dtype: object

# %%
condition_onset_date_time = condition_data.get('resource.onsetDateTime',None)
condition_onset_date_time
# Out:
# 0      2010-07-31T13:21:25-04:00
# 1      2010-09-13T01:03:45-04:00
# 2      2011-10-24T04:05:30-04:00
# 3      2015-01-05T19:01:24-05:00
# 4      2015-05-08T20:38:47-04:00
#                  ...
# 146    1997-06-15T17:23:53-04:00
# 147    2009-12-24T08:58:07-05:00
# 148    2012-02-17T18:52:24-05:00
# 149    2014-02-07T22:43:10-05:00
# 150    2014-02-05T10:51:00-05:00
# Name: resource.onsetDateTime, Length: 151, dtype: object

# %%
condition_abatement_date_time = condition_data.get('resource.abatementDateTime',None)
condition_abatement_date_time
# Out:
# 0      2010-08-13T01:03:45-04:00
# 1      2010-09-25T17:29:09-04:00
# 2      2011-11-12T01:05:15-05:00
# 3      2015-01-28T12:23:23-05:00
# 4      2015-12-04T20:38:47-05:00
#                  ...
# 146                          NaN
# 147    2010-03-06T03:41:56-05:00
# 148    2012-03-05T10:51:00-05:00
# 149    2014-05-18T12:43:32-04:00
# 150    2014-03-02T21:47:33-05:00
# Name: resource.abatementDateTime, Length: 151, dtype: object

# %%
condition_patient_id = condition_data['resource.subject.reference'].str.replace('urn:uuid:','')
condition_patient_id
# Out:
# 0      65d12976-9588-4cfa-a795-216302a2ece9
# 1      65d12976-9588-4cfa-a795-216302a2ece9
# 2      65d12976-9588-4cfa-a795-216302a2ece9
# 3      65d12976-9588-4cfa-a795-216302a2ece9
# 4      65d12976-9588-4cfa-a795-216302a2ece9
#                        ...
# 146    a5399e95-981c-4a78-8019-873662fc7901
# 147    a5399e95-981c-4a78-8019-873662fc7901
# 148    a5399e95-981c-4a78-8019-873662fc7901
# 149    a5399e95-981c-4a78-8019-873662fc7901
# 150    a5399e95-981c-4a78-8019-873662fc7901
# Name: resource.subject.reference, Length: 151, dtype: object

# %%
condition_encounter_id  = condition_data['resource.context.reference'].str.replace('urn:uuid:','')
condition_encounter_id
# Out:
# 0      a3e3bd43-ef3c-48fd-9851-5302d1aa84c6
# 1      7e969f44-f034-48c1-82c9-0fcf4b24e20c
# 2      8c679a80-a381-4fa8-af8a-31cb44d65b7b
# 3      ddc2fb3c-6ea7-4b66-931b-0a0b4bfd3a75
# 4      80fd8fc5-4770-4e35-b31c-4d7b1be19c2f
#                        ...
# 146    14e39e12-688a-4a2d-942d-d761cff4123e
# 147    14e39e12-688a-4a2d-942d-d761cff4123e
# 148    cb364aed-12ed-4c24-94b4-56e829635d72
# 149    7f88e6e7-b838-497a-86d6-aaf35b8cdf29
# 150    7f88e6e7-b838-497a-86d6-aaf35b8cdf29
# Name: resource.context.reference, Length: 151, dtype: object

# %%
result_df = pd.DataFrame({
    'Condition ID':condition_id,
    'Clinical Status':condition_clinical_status,
    'Verification Status':condition_verification_status,
    'Condition Name':condition_name,
    'Patient ID':condition_patient_id,
    'Encounter ID':condition_encounter_id,
    'Onset Date Time':condition_onset_date_time,
    'Abatement Date Time':condition_abatement_date_time
})
result_df.head()
# Out:
#                            Condition ID Clinical Status Verification Status  \
# 0  dff431d5-79b9-40c0-91b6-e3032cf93a20          active           confirmed
# 1  be9865e1-76d5-4e23-b94d-7e3da3c0e762          active           confirmed
# 2  3f257d68-ea56-42b5-b926-74165e287c62          active           confirmed
# 3  bda57d2c-732a-4f5b-a0bc-f9b49ca45cb0          active           confirmed
# 4  41b412e2-fc7f-4f0d-8a31-cf793c1426e5          active           confirmed
#
#                          Condition Name                            Patient ID  \
# 0  Streptococcal sore throat (disorder)  65d12976-9588-4cfa-a795-216302a2ece9
# 1    Acute viral pharyngitis (disorder)  65d12976-9588-4cfa-a795-216302a2ece9
# 2            Viral sinusitis (disorder)  65d12976-9588-4cfa-a795-216302a2ece9
# 3           Acute bronchitis (disorder)  65d12976-9588-4cfa-a795-216302a2ece9
# 4                      Normal pregnancy  65d12976-9588-4cfa-a795-216302a2ece9
#
#                            Encounter ID            Onset Date Time  \
# 0  a3e3bd43-ef3c-48fd-9851-5302d1aa84c6  2010-07-31T13:21:25-04:00
# 1  7e969f44-f034-48c1-82c9-0fcf4b24e20c  2010-09-13T01:03:45-04:00
# 2  8c679a80-a381-4fa8-af8a-31cb44d65b7b  2011-10-24T04:05:30-04:00
# 3  ddc2fb3c-6ea7-4b66-931b-0a0b4bfd3a75  2015-01-05T19:01:24-05:00
# 4  80fd8fc5-4770-4e35-b31c-4d7b1be19c2f  2015-05-08T20:38:47-04:00
#
#          Abatement Date Time
# 0  2010-08-13T01:03:45-04:00
# 1  2010-09-25T17:29:09-04:00
# 2  2011-11-12T01:05:15-05:00
# 3  2015-01-28T12:23:23-05:00
# 4  2015-12-04T20:38:47-05:00

# %% [markdown]
# ## Condition Data Extraction

# %%
import pandas as pd
import glob

# %%
def extract_condition_data(root_directory_path):
    file_paths = glob.glob(f"{root_directory_path}*.json")
    dfs = [pd.read_json(file_path) for file_path in file_paths]
    combined_df = pd.concat(dfs, ignore_index=True)
    entries = pd.json_normalize(combined_df['entry'])

    condition_data = entries[entries['resource.resourceType'] == 'Condition']
    condition_data.reset_index(drop=True,inplace=True)

    condition_id = condition_data['resource.id']
    condition_clinical_status = condition_data.get('resource.clinicalStatus',None)
    condition_verification_status = condition_data.get('resource.verificationStatus',None)
    condition_name_raw = condition_data.get('resource.code.coding',None)
    if not condition_name_raw is None:
        condition_name = pd.json_normalize(condition_name_raw.explode()).get('display',None)
    else:
        condition_name = None
    condition_onset_date_time = condition_data.get('resource.onsetDateTime',None)
    condition_abatement_date_time = condition_data.get('resource.abatementDateTime',None)
    condition_patient_id = condition_data['resource.subject.reference'].str.replace('urn:uuid:','')
    condition_encounter_id  = condition_data['resource.context.reference'].str.replace('urn:uuid:','')

    result_df = pd.DataFrame({
    'Condition ID':condition_id,
    'Clinical Status':condition_clinical_status,
    'Verification Status':condition_verification_status,
    'Condition Name':condition_name,
    'Patient ID':condition_patient_id,
    'Encounter ID':condition_encounter_id,
    'Onset Date Time':condition_onset_date_time,
    'Abatement Date Time':condition_abatement_date_time
    })

    result_df.to_csv('./output_csv/condition_data.csv',index=False)

# %%
extract_condition_data('./health_data/healthcare-datasets/')

# %% [markdown]
# ## Process Condition Data

# %%
import pandas as pd
condition = pd.read_csv('./output_csv/condition_data.csv')

# %%
condition.head()
# Out:
#                            Condition ID Clinical Status Verification Status  \
# 0  dff431d5-79b9-40c0-91b6-e3032cf93a20          active           confirmed
# 1  be9865e1-76d5-4e23-b94d-7e3da3c0e762          active           confirmed
# 2  3f257d68-ea56-42b5-b926-74165e287c62          active           confirmed
# 3  bda57d2c-732a-4f5b-a0bc-f9b49ca45cb0          active           confirmed
# 4  41b412e2-fc7f-4f0d-8a31-cf793c1426e5          active           confirmed
#
#                          Condition Name                            Patient ID  \
# 0  Streptococcal sore throat (disorder)  65d12976-9588-4cfa-a795-216302a2ece9
# 1    Acute viral pharyngitis (disorder)  65d12976-9588-4cfa-a795-216302a2ece9
# 2            Viral sinusitis (disorder)  65d12976-9588-4cfa-a795-216302a2ece9
# 3           Acute bronchitis (disorder)  65d12976-9588-4cfa-a795-216302a2ece9
# 4                      Normal pregnancy  65d12976-9588-4cfa-a795-216302a2ece9
#
#                            Encounter ID            Onset Date Time  \
# 0  a3e3bd43-ef3c-48fd-9851-5302d1aa84c6  2010-07-31T13:21:25-04:00
# 1  7e969f44-f034-48c1-82c9-0fcf4b24e20c  2010-09-13T01:03:45-04:00
# 2  8c679a80-a381-4fa8-af8a-31cb44d65b7b  2011-10-24T04:05:30-04:00
# 3  ddc2fb3c-6ea7-4b66-931b-0a0b4bfd3a75  2015-01-05T19:01:24-05:00
# 4  80fd8fc5-4770-4e35-b31c-4d7b1be19c2f  2015-05-08T20:38:47-04:00
#
#          Abatement Date Time
# 0  2010-08-13T01:03:45-04:00
# 1  2010-09-25T17:29:09-04:00
# 2  2011-11-12T01:05:15-05:00
# 3  2015-01-28T12:23:23-05:00
# 4  2015-12-04T20:38:47-05:00

# %%
condition.describe()
# Out:
#                                 Condition ID Clinical Status  \
# count                                    151             151
# unique                                   151               1
# top     dff431d5-79b9-40c0-91b6-e3032cf93a20          active
# freq                                       1             151
#
#        Verification Status              Condition Name  \
# count                  151                         151
# unique                   1                          48
# top              confirmed  Viral sinusitis (disorder)
# freq                   151                          22
#
#                                   Patient ID  \
# count                                    151
# unique                                    34
# top     aa3973d9-b64f-4a36-8cb6-f2719080b52f
# freq                                      10
#
#                                 Encounter ID            Onset Date Time  \
# count                                    151                        151
# unique                                   106                        148
# top     fee0f09f-2c53-46e9-a50f-fe69d3238996  2011-06-15T04:14:23-04:00
# freq                                       7                          2
#
#               Abatement Date Time
# count                          91
# unique                         89
# top     2013-06-18T19:56:52-04:00
# freq                            2

# %%
condition.groupby('Patient ID')['Condition ID'].nunique()
# Out:
# Patient ID
# 00d869e2-6793-4ebf-9340-38bf18d223c4     2
# 117335bb-33ff-4897-ac27-af4b3f11135f     5
# 1694897b-912e-401f-a135-aa59857a401e     4
# 1bd855fa-45c4-4c23-a608-fdeeb3bc2d8b     4
# 21e19329-b572-414b-9cd1-ecf96af4f568     3
# 2db81051-c02a-4c72-b17d-feb8c49cded7     2
# 2f3f9a7e-8142-40c8-8c4a-b58bc815b48d     6
# 32c72cdb-66bf-4301-895e-16da54ffd72d     3
# 3a5357d9-13f3-42de-8fdc-14a1a6cae148     3
# 509474a0-baf3-48f2-a595-67b6e2b34c87     4
# 5265a2b0-1bbc-4993-9042-b8d86ba65f10     2
# 65d12976-9588-4cfa-a795-216302a2ece9     5
# 65dfe191-c7ef-4148-8f12-49f832525d4c     2
# 7384d82c-2d1e-4595-99e4-f0ae962dddf1     9
# 80bb41d3-ebb4-42e6-b087-6ee89b0463a9     1
# 83044f55-e41f-4489-a0b8-f69bd6c7b1d4     7
# 8b47143f-2d3b-4425-a872-569af4ec0818     2
# 95ad0405-ec9e-4464-a708-750296dc1548     1
# 99937389-654f-4a48-8e74-ac81cf260e0f     6
# 9bf6df85-12db-49d1-b754-b5adcdbb6115     4
# a0dcd747-1d40-40fd-8e42-1f9395f034ca     8
# a195633e-d36d-4abe-92bb-02994e9cb348     5
# a5399e95-981c-4a78-8019-873662fc7901     5
# aa3973d9-b64f-4a36-8cb6-f2719080b52f    10
# aeb76067-0f32-40a2-a29d-dfe7c4ab6638     1
# bb357dc7-2f8a-444e-ba57-8291b6f18bf0     5
# bd0acd69-580e-4896-9974-2ad9d041ca0b     9
# c71d235f-9b58-4106-b744-c554da5e13fa     7
# c92cad20-6dd1-4e22-b3d9-6f0507854a96     6
# cb13a48a-0dea-40c9-8eeb-8e275e101e5d     3
# d0ed1873-9ac6-4c98-813e-86a041ce78c5     5
# d76cce33-3dec-4874-b352-fa81812517c7     2
# ddd6fcc5-4a60-450d-a55c-927113ec312e     9
# f10fd607-58ce-4be6-b1bd-a98898c8e0e5     1
# Name: Condition ID, dtype: int64

# %%
pd.set_option('display.max_colwidth',90)
test = condition.groupby('Patient ID').agg({
    'Condition ID':lambda x : list(x.unique()),
})
test['condition count'] = condition.groupby('Patient ID')['Condition ID'].nunique()
test
# Out:
#                                                                                                                    Condition ID  \
# Patient ID
# 00d869e2-6793-4ebf-9340-38bf18d223c4               [ac19c6a8-3fef-4d1f-bf34-dd04b49bff08, 3933d233-e42b-446f-b6d5-2124f7d650e6]
# 117335bb-33ff-4897-ac27-af4b3f11135f  [55b30910-470a-4d6c-b56d-aa699cc9156b, 1079f9a4-52a7-4817-9e32-bad6de7ce87d, 85d0c325-...
# 1694897b-912e-401f-a135-aa59857a401e  [6434e601-c857-42ce-8e31-44cecaaf339d, 0224be83-6997-4803-add1-56f04219d779, 663b9e49-...
# 1bd855fa-45c4-4c23-a608-fdeeb3bc2d8b  [2af9dbad-2c1c-470d-8bec-ad650890b1d3, 1cac2d6a-34c2-4ff5-ad0a-a50e5ea39752, a552ee4e-...
# 21e19329-b572-414b-9cd1-ecf96af4f568  [441115a2-353d-444a-820e-30c124efc0b7, 16d98a1d-ba9d-450e-b7ce-889218ac9b93, ec5aec6e-...
# 2db81051-c02a-4c72-b17d-feb8c49cded7               [a3b890c1-948a-4123-841d-cbe76443ecba, 4e0c6c9c-44ee-4d17-89b1-d9e9e00a87bd]
# 2f3f9a7e-8142-40c8-8c4a-b58bc815b48d  [1e194f7f-32c6-49b5-bc9b-318abf331d4a, 4925052d-c697-4537-9152-a16a8061e8bb, f1afb4ed-...
# 32c72cdb-66bf-4301-895e-16da54ffd72d  [4c9209c1-9145-49d8-9dbc-87dce876ef64, 5e7c8a39-5a49-4c2a-b306-745d6d445df2, 02200242-...
# 3a5357d9-13f3-42de-8fdc-14a1a6cae148  [08def035-2c6d-4947-991f-0c09538d16b4, 5d2d33e7-36c5-46c6-8241-e653a78486b3, 855eadd7-...
# 509474a0-baf3-48f2-a595-67b6e2b34c87  [61e4b744-f0c6-467d-bcaf-2a1cf1b5c134, 03fe68de-4165-4514-8f38-91b9b03d9d26, 2114bfc8-...
# 5265a2b0-1bbc-4993-9042-b8d86ba65f10               [457c2608-0f23-4b88-b6c9-9f396ff4d363, 6d76a441-314d-4819-b406-a543730ae82d]
# 65d12976-9588-4cfa-a795-216302a2ece9  [dff431d5-79b9-40c0-91b6-e3032cf93a20, be9865e1-76d5-4e23-b94d-7e3da3c0e762, 3f257d68-...
# 65dfe191-c7ef-4148-8f12-49f832525d4c               [b6d733fe-8090-4fef-9430-9b8000fb44c3, 641e196a-b2c6-41ff-a0a5-120d1cb3e419]
# 7384d82c-2d1e-4595-99e4-f0ae962dddf1  [b5432557-f61c-4fdb-8a4b-517a0d80a35a, 2a1a7ced-d6f8-4c3c-85f9-ed037bb8c96b, c84facda-...
# 80bb41d3-ebb4-42e6-b087-6ee89b0463a9                                                     [593c21c4-8cce-47cd-bd70-41e4a7b25557]
# 83044f55-e41f-4489-a0b8-f69bd6c7b1d4  [f78d7691-4a98-4c30-b55c-8ea555acea5e, f3037cb4-8886-48dc-a22c-ef6f0f398b3a, 2463e658-...
# 8b47143f-2d3b-4425-a872-569af4ec0818               [76d7f42b-358d-417c-8929-c9144255da69, 29742796-606c-41f9-9525-a988e39410cb]
# 95ad0405-ec9e-4464-a708-750296dc1548                                                     [4238c65f-216c-4f75-b99b-e79880fccc80]
# 99937389-654f-4a48-8e74-ac81cf260e0f  [81bcf73d-7392-453e-af1c-4f38250f139a, 31e0ccf0-f65b-4b62-a9fd-e235f9431b84, a38ad564-...
# 9bf6df85-12db-49d1-b754-b5adcdbb6115  [93cfd203-eb61-4099-9bd3-73b8fbabf1c8, 09e10454-428d-4e3e-8e13-bcbf62db1bcd, 0b329e37-...
# a0dcd747-1d40-40fd-8e42-1f9395f034ca  [5b71f147-ef34-497e-b8a0-3c2b7cafeee7, dd52ae37-7daf-4240-a938-731d8c55fd00, 2fa287c8-...
# a195633e-d36d-4abe-92bb-02994e9cb348  [4f79cfae-3c81-4f18-9ce4-691f008d4ddb, 844decaa-dccd-4da0-8ba1-ab7e2ca6948b, b7f12189-...
# a5399e95-981c-4a78-8019-873662fc7901  [ff5133e8-6d61-46f4-aa79-446533960eac, e827d0e4-a1d9-49e3-9edf-038319e25ed3, fa532314-...
# aa3973d9-b64f-4a36-8cb6-f2719080b52f  [16f94f06-ac1a-4243-b364-947305b3edef, b4690eab-bbd4-454b-99f1-51ac86fd12dd, f2128f2f-...
# aeb76067-0f32-40a2-a29d-dfe7c4ab6638                                                     [4ac980e6-7a24-4071-83c9-61734611f7b7]
# bb357dc7-2f8a-444e-ba57-8291b6f18bf0  [8a909708-9137-43b9-9672-484ec567f86b, 4eee0d5a-1999-4af9-8c06-21d8447ab278, 8248e30d-...
# bd0acd69-580e-4896-9974-2ad9d041ca0b  [fa31f030-35e6-49fe-8f86-b1971de99849, 931490ee-4ac7-4cf1-a291-ce8a485e7c61, 93d6f1e1-...
# c71d235f-9b58-4106-b744-c554da5e13fa  [66868a39-d41a-4acb-a3a2-202093909119, c313696c-498c-4867-967b-c9c1a4938aa2, 8848e39c-...
# c92cad20-6dd1-4e22-b3d9-6f0507854a96  [1118f6cf-289d-4bde-9398-cee59e2265d3, afb5c211-4373-427c-9d91-6b651d510405, ce124911-...
# cb13a48a-0dea-40c9-8eeb-8e275e101e5d  [d7ef61ac-6441-4cf1-ad33-5e008719c458, cdb2c237-7b08-466e-90e0-506aff5ce3a5, 22fd1bfa-...
# d0ed1873-9ac6-4c98-813e-86a041ce78c5  [bbeebb22-6193-4601-b81d-00d5d462fcc2, 493a6882-d653-4d86-8d00-bb6f93e15daf, 5afd31cc-...
# d76cce33-3dec-4874-b352-fa81812517c7               [be98e887-dfce-4dbc-855d-6d1c569f1360, 2d6fa5fa-3f28-4fa7-863a-d3967e6b7eb1]
# ddd6fcc5-4a60-450d-a55c-927113ec312e  [f7b8fa3f-0e0b-4205-8ed5-1e87169c8fb4, b419d619-82de-423c-95b0-a43320e6d60e, f1e0428b-...
# f10fd607-58ce-4be6-b1bd-a98898c8e0e5                                                     [33cdf2a5-08af-476d-aab4-b54d7d78c43e]
#
#                                       condition count
# Patient ID
# 00d869e2-6793-4ebf-9340-38bf18d223c4                2
# 117335bb-33ff-4897-ac27-af4b3f11135f                5
# 1694897b-912e-401f-a135-aa59857a401e                4
# 1bd855fa-45c4-4c23-a608-fdeeb3bc2d8b                4
# 21e19329-b572-414b-9cd1-ecf96af4f568                3
# 2db81051-c02a-4c72-b17d-feb8c49cded7                2
# 2f3f9a7e-8142-40c8-8c4a-b58bc815b48d                6
# 32c72cdb-66bf-4301-895e-16da54ffd72d                3
# 3a5357d9-13f3-42de-8fdc-14a1a6cae148                3
# 509474a0-baf3-48f2-a595-67b6e2b34c87                4
# 5265a2b0-1bbc-4993-9042-b8d86ba65f10                2
# 65d12976-9588-4cfa-a795-216302a2ece9                5
# 65dfe191-c7ef-4148-8f12-49f832525d4c                2
# 7384d82c-2d1e-4595-99e4-f0ae962dddf1                9
# 80bb41d3-ebb4-42e6-b087-6ee89b0463a9                1
# 83044f55-e41f-4489-a0b8-f69bd6c7b1d4                7
# 8b47143f-2d3b-4425-a872-569af4ec0818                2
# 95ad0405-ec9e-4464-a708-750296dc1548                1
# 99937389-654f-4a48-8e74-ac81cf260e0f                6
# 9bf6df85-12db-49d1-b754-b5adcdbb6115                4
# a0dcd747-1d40-40fd-8e42-1f9395f034ca                8
# a195633e-d36d-4abe-92bb-02994e9cb348                5
# a5399e95-981c-4a78-8019-873662fc7901                5
# aa3973d9-b64f-4a36-8cb6-f2719080b52f               10
# aeb76067-0f32-40a2-a29d-dfe7c4ab6638                1
# bb357dc7-2f8a-444e-ba57-8291b6f18bf0                5
# bd0acd69-580e-4896-9974-2ad9d041ca0b                9
# c71d235f-9b58-4106-b744-c554da5e13fa                7
# c92cad20-6dd1-4e22-b3d9-6f0507854a96                6
# cb13a48a-0dea-40c9-8eeb-8e275e101e5d                3
# d0ed1873-9ac6-4c98-813e-86a041ce78c5                5
# d76cce33-3dec-4874-b352-fa81812517c7                2
# ddd6fcc5-4a60-450d-a55c-927113ec312e                9
# f10fd607-58ce-4be6-b1bd-a98898c8e0e5                1
