# %%
import pandas as pd

# %%
df = pd.read_json("test.json")

# %%
entries = pd.json_normalize(df.entry)

# %%
#Patient, Encounter, Procedure, Immunization, Diagnostic Report

patient_data = entries[entries["resource.resourceType"]=="Patient"]
encounter_data = entries[entries["resource.resourceType"]=="Encounter"]
procedure_data = entries[entries["resource.resourceType"]=="Procedure"]
immunization_data = entries[entries["resource.resourceType"]=="Immunization"]
diagnostic_data = entries[entries["resource.resourceType"]=="DiagnosticReport"]

# %%
#encouter id, status,class,type, start_date, end_date, pateientID,
encounter_id = encounter_data["resource.id"]
encounter_class = encounter_data["resource.class.code"]
encounter_status = encounter_data["resource.status"]
encounter_start_date = encounter_data["resource.period.start"]
encounter_end_date = encounter_data["resource.period.end"]
encounter_patient_relation = pd.merge(patient_data,encounter_data,left_on="fullUrl",right_on="resource.patient.reference")
encounter_patient_id=encounter_patient_relation["resource.id_x"]

encounter_output = pd.DataFrame([encounter_id,encounter_status,encounter_class,encounter_start_date,encounter_end_date,encounter_patient_id])
encounter_output.T
# Out:
#                               resource.id resource.status resource.class.code  \
# 1    fee0f09f-2c53-46e9-a50f-fe69d3238996        finished          outpatient
# 38   6e177a9b-d986-4e75-92af-5b9b1683d422        finished          ambulatory
# 43   66c3a37c-0d5f-4488-9e49-263c760e7f6c        finished           emergency
# 48   d8294703-8020-4f30-b8b5-01b76624d85c        finished          outpatient
# 72   0a4e4fe4-13e3-486d-b090-03093669f7f3        finished          outpatient
# 96   1696a51a-fbb7-4a7a-9004-bb2ea5094087        finished          outpatient
# 120  9c6ee96e-445f-42b9-a711-d8acb2788bc3        finished          outpatient
# 144  a6eea737-086c-4905-9075-e6ef68624267        finished          ambulatory
# 146  01e1e451-d7c5-4876-b4e7-d499eaada844        finished          outpatient
# 171  638fee81-9b8f-4896-8536-407e34db67c0        finished          outpatient
# 196  ba8b290e-98ba-4c40-90bd-a0a500b339b8        finished          outpatient
# ...

# %%
encounter_output = pd.concat([encounter_id,encounter_status,encounter_class,encounter_start_date,encounter_end_date,encounter_patient_id],axis=1)
encounter_output
# Out:
#                               resource.id resource.status resource.class.code  \
# 1    fee0f09f-2c53-46e9-a50f-fe69d3238996        finished          outpatient
# 38   6e177a9b-d986-4e75-92af-5b9b1683d422        finished          ambulatory
# 43   66c3a37c-0d5f-4488-9e49-263c760e7f6c        finished           emergency
# 48   d8294703-8020-4f30-b8b5-01b76624d85c        finished          outpatient
# 72   0a4e4fe4-13e3-486d-b090-03093669f7f3        finished          outpatient
# 96   1696a51a-fbb7-4a7a-9004-bb2ea5094087        finished          outpatient
# 120  9c6ee96e-445f-42b9-a711-d8acb2788bc3        finished          outpatient
# 144  a6eea737-086c-4905-9075-e6ef68624267        finished          ambulatory
# 146  01e1e451-d7c5-4876-b4e7-d499eaada844        finished          outpatient
# 171  638fee81-9b8f-4896-8536-407e34db67c0        finished          outpatient
# 196  ba8b290e-98ba-4c40-90bd-a0a500b339b8        finished          outpatient
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d017257e-8148-4001-aa6c-0055af14000b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
