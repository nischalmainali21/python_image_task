# %%
import pandas as pd
import glob

# %%
file_paths = glob.glob(f"./health_data/healthcare-datasets/*.json")
dfs = [pd.read_json(file_path) for file_path in file_paths]
combined_df = pd.concat(dfs, ignore_index=True)
entries = pd.json_normalize(combined_df['entry'])

# %%
entries['resource.resourceType'].unique()
# Out:
# array(['Patient', 'Encounter', 'Condition', 'Observation', 'Immunization',
#        'CarePlan', 'Procedure', 'DiagnosticReport', 'MedicationRequest',
#        'AllergyIntolerance'], dtype=object)

# %%
observation_data = entries[entries['resource.resourceType'] == 'Observation']
observation_data.reset_index(drop=True,inplace=True)
observation_data.head()
# Out:
#                                          fullUrl  \
# 0  urn:uuid:1f954180-ec49-455a-95aa-3b7414ffeab6
# 1  urn:uuid:556966e3-42a8-4359-838a-8771dd2a2a23
# 2  urn:uuid:5e1608af-47b2-4990-af09-50d3ca7a62b9
# 3  urn:uuid:7b141a9c-6c37-4d06-8eb8-4c61c5ca4bf0
# 4  urn:uuid:cac21874-494f-49f6-8074-1d517a62a7d3
#
#                             resource.id resource.text.status  \
# 0  1f954180-ec49-455a-95aa-3b7414ffeab6                  NaN
# 1  556966e3-42a8-4359-838a-8771dd2a2a23                  NaN
# 2  5e1608af-47b2-4990-af09-50d3ca7a62b9                  NaN
# 3  7b141a9c-6c37-4d06-8eb8-4c61c5ca4bf0                  NaN
# 4  cac21874-494f-49f6-8074-1d517a62a7d3                  NaN
#
#   resource.text.div resource.extension resource.identifier resource.name  \
# 0               NaN                NaN                 NaN           NaN
# 1               NaN                NaN                 NaN           NaN
# 2               NaN                NaN                 NaN           NaN
# 3               NaN                NaN                 NaN           NaN
# 4               NaN                NaN                 NaN           NaN
#
#   resource.telecom resource.gender resource.birthDate  ...  \
# 0              NaN             NaN                NaN  ...
# 1              NaN             NaN                NaN  ...
# 2              NaN             NaN                NaN  ...
# 3              NaN             NaN                NaN  ...
# 4              NaN             NaN                NaN  ...
#
#   resource.dispenseRequest.numberOfRepeatsAllowed  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   resource.dispenseRequest.quantity.value  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   resource.dispenseRequest.quantity.unit  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   resource.dispenseRequest.expectedSupplyDuration.value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   resource.dispenseRequest.expectedSupplyDuration.unit  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   resource.dispenseRequest.expectedSupplyDuration.system  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   resource.dispenseRequest.expectedSupplyDuration.code resource.criticality  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#   resource.assertedDate resource.multipleBirthInteger
# 0                   NaN                           NaN
# 1                   NaN                           NaN
# 2                   NaN                           NaN
# 3                   NaN                           NaN
# 4                   NaN                           NaN
#
# [5 rows x 68 columns]

# %%
observation_id = observation_data.get('resource.id',None)
observation_id
# Out:
# 0       1f954180-ec49-455a-95aa-3b7414ffeab6
# 1       556966e3-42a8-4359-838a-8771dd2a2a23
# 2       5e1608af-47b2-4990-af09-50d3ca7a62b9
# 3       7b141a9c-6c37-4d06-8eb8-4c61c5ca4bf0
# 4       cac21874-494f-49f6-8074-1d517a62a7d3
#                         ...
# 1305    e4e56824-be5d-40f5-800e-052841b16eea
# 1306    b7b2e34e-b5a2-4879-9305-e20d9df9d6f5
# 1307    ed9fbc19-242d-4044-8900-1e43f62dd116
# 1308    1102d6e4-724c-4593-bbc4-81416860431f
# 1309    6643ee4f-9fa9-430f-a456-a2e39ebc7bbd
# Name: resource.id, Length: 1310, dtype: object

# %%
observation_status = observation_data.get('resource.status',None)
observation_status
# Out:
# 0       final
# 1       final
# 2       final
# 3       final
# 4       final
#         ...
# 1305    final
# 1306    final
# 1307    final
# 1308    final
# 1309    final
# Name: resource.status, Length: 1310, dtype: object

# %%
observation_type_raw = observation_data.get('resource.code.coding',None)
if not observation_type_raw is None:
    display(observation_type_raw)
    observation_type = pd.json_normalize(observation_type_raw.explode()).get('display',None)
    display(observation_type)
else:
    observation_type = None
# Out:
# 0       [{'system': 'http://loinc.org', 'code': '8302-...
# 1       [{'system': 'http://loinc.org', 'code': '29463...
# 2       [{'system': 'http://loinc.org', 'code': '39156...
# 3       [{'system': 'http://loinc.org', 'code': '55284...
# 4       [{'system': 'http://loinc.org', 'code': '8302-...
#                               ...
# 1305    [{'system': 'http://loinc.org', 'code': '2571-...
# 1306    [{'system': 'http://loinc.org', 'code': '18262...
# 1307    [{'system': 'http://loinc.org', 'code': '2085-...
# 1308    [{'system': 'http://loinc.org', 'code': '14959...
# 1309    [{'system': 'http://loinc.org', 'code': '33914...
# Name: resource.code.coding, Length: 1310, dtype: object
# 0                                Body Height
# 1                                Body Weight
# 2                            Body Mass Index
# 3                             Blood Pressure
# 4                                Body Height
#                         ...
# 1305                           Triglycerides
# 1306     Low Density Lipoprotein Cholesterol
# 1307    High Density Lipoprotein Cholesterol
# 1308             Microalbumin Creatine Ratio
# 1309    Estimated Glomerular Filtration Rate
# Name: display, Length: 1310, dtype: object

# %%
observation_data.columns
# Out:
# Index(['fullUrl', 'resource.id', 'resource.text.status', 'resource.text.div',
#        'resource.extension', 'resource.identifier', 'resource.name',
#        'resource.telecom', 'resource.gender', 'resource.birthDate',
#        'resource.address', 'resource.maritalStatus.coding',
#        'resource.multipleBirthBoolean', 'resource.photo',
#        'resource.resourceType', 'resource.status', 'resource.class.code',
#        'resource.type', 'resource.patient.reference', 'resource.period.start',
#        'resource.period.end', 'resource.clinicalStatus',
#        'resource.verificationStatus', 'resource.code.coding',
#        'resource.subject.reference', 'resource.context.reference',
#        'resource.onsetDateTime', 'resource.abatementDateTime',
#        'resource.encounter.reference', 'resource.effectiveDateTime',
#        'resource.valueQuantity.value', 'resource.valueQuantity.unit',
#        'resource.valueQuantity.system', 'resource.valueQuantity.code',
#        'resource.component', 'resource.date', 'resource.vaccineCode.coding',
#        'resource.wasNotGiven', 'resource.primarySource', 'resource.category',
#        'resource.activity', 'resource.code.text',
#        'resource.performedPeriod.start', 'resource.performedPeriod.end',
#        'resource.issued', 'resource.performer', 'resource.result',
#        'resource.performedDateTime', 'resource.addresses',
#        'resource.reason.coding', 'resource.stage.coding',
#        'resource.medicationCodeableConcept.coding', 'resource.dateWritten',
#        'resource.reasonReference', 'resource.dosageInstruction',
#        'resource.reasonReference.reference', 'resource.deceasedDateTime',
#        'resource.valueCodeableConcept.coding',
#        'resource.dispenseRequest.numberOfRepeatsAllowed',
#        'resource.dispenseRequest.quantity.value',
#        'resource.dispenseRequest.quantity.unit',
#        'resource.dispenseRequest.expectedSupplyDuration.value',
#        'resource.dispenseRequest.expectedSupplyDuration.unit',
#        'resource.dispenseRequest.expectedSupplyDuration.system',
#        'resource.dispenseRequest.expectedSupplyDuration.code',
#        'resource.criticality', 'resource.assertedDate',
#        'resource.multipleBirthInteger'],
#       dtype='object')

# %%
observation_value = observation_data.get('resource.valueQuantity.value',None).apply(lambda x: round(x,1))
display(len(observation_value))
observation_unit = observation_data.get('resource.valueQuantity.unit',None)
display(len(observation_unit))
if not observation_value is None:
    observation_value_unit = observation_value.astype('str').str.cat(observation_unit,sep=' ')
    display(observation_value_unit)
else:
    observation_value_unit = None
# Out:
# 1310
# 1310
# 0                   158.9 cm
# 1                    98.0 kg
# 2                 38.8 kg/m2
# 3                        NaN
# 4                   158.9 cm
#                 ...
# 1305             100.0 mg/dL
# 1306              91.0 mg/dL
# 1307              75.0 mg/dL
# 1308               12.0 mg/g
# 1309    0.0 mL/min/{1.73_m2}
# Name: resource.valueQuantity.value, Length: 1310, dtype: object

# %%
len(observation_value_unit[observation_value_unit.isna()])
# Out:
# 163

# %%
observation_date_time = observation_data.get('resource.effectiveDateTime',None)
observation_date_time
# Out:
# 0       2010-05-12T10:33:51-04:00
# 1       2010-05-12T10:33:51-04:00
# 2       2010-05-12T10:33:51-04:00
# 3       2010-05-12T10:33:51-04:00
# 4       2011-07-02T14:56:51-04:00
#                   ...
# 1305    2017-01-25T15:04:04-05:00
# 1306    2017-01-25T15:04:04-05:00
# 1307    2017-01-25T15:04:04-05:00
# 1308    2017-01-25T15:04:04-05:00
# 1309    2017-01-25T15:04:04-05:00
# Name: resource.effectiveDateTime, Length: 1310, dtype: object

# %%
observation_encounter_id = observation_data['resource.encounter.reference'].str.replace('urn:uuid:','')
observation_patient_id = observation_data['resource.subject.reference'].str.replace('urn:uuid:','')

# %% [markdown]
# result

# %%
result_df = pd.DataFrame({
    'Observation ID':observation_id,
    'Status':observation_status,
    'Patient ID':observation_patient_id,
    'Encounter ID':observation_encounter_id,
    'Observation Date Time':observation_date_time,
    'Observation Type':observation_type,
    'Observation Value':observation_value_unit
})
result_df.head()
# Out:
#                          Observation ID Status  \
# 0  1f954180-ec49-455a-95aa-3b7414ffeab6  final
# 1  556966e3-42a8-4359-838a-8771dd2a2a23  final
# 2  5e1608af-47b2-4990-af09-50d3ca7a62b9  final
# 3  7b141a9c-6c37-4d06-8eb8-4c61c5ca4bf0  final
# 4  cac21874-494f-49f6-8074-1d517a62a7d3  final
#
#                              Patient ID                          Encounter ID  \
# 0  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  2c722ad1-5a59-4f6a-90cc-c55f86bbd9c6
# 1  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  2c722ad1-5a59-4f6a-90cc-c55f86bbd9c6
# 2  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  2c722ad1-5a59-4f6a-90cc-c55f86bbd9c6
# 3  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  2c722ad1-5a59-4f6a-90cc-c55f86bbd9c6
# 4  80bb41d3-ebb4-42e6-b087-6ee89b0463a9  f5b01614-f569-4e9e-b482-cc0231a7c20a
#
#        Observation Date Time Observation Type Observation Value
# 0  2010-05-12T10:33:51-04:00      Body Height          158.9 cm
# 1  2010-05-12T10:33:51-04:00      Body Weight           98.0 kg
# 2  2010-05-12T10:33:51-04:00  Body Mass Index        38.8 kg/m2
# 3  2010-05-12T10:33:51-04:00   Blood Pressure               NaN
# 4  2011-07-02T14:56:51-04:00      Body Height          158.9 cm

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Observation ID         1310 non-null   object
#  1   Status                 1310 non-null   object
#  2   Patient ID             1310 non-null   object
#  3   Encounter ID           1310 non-null   object
#  4   Observation Date Time  1310 non-null   object
#  5   Observation Type       1310 non-null   object
#  6   Observation Value      1147 non-null   object
# dtypes: object(7)
# memory usage: 71.8+ KB

# %%
len(result_df['Encounter ID'].unique())
# Out:
# 189

# %%
result_df.describe()
# Out:
#                               Observation ID Status  \
# count                                   1310   1310
# unique                                  1310      1
# top     1f954180-ec49-455a-95aa-3b7414ffeab6  final
# freq                                       1   1310
#
#                                   Patient ID  \
# count                                   1310
# unique                                    34
# top     aa3973d9-b64f-4a36-8cb6-f2719080b52f
# freq                                     181
#
#                                 Encounter ID      Observation Date Time  \
# count                                   1310                       1310
# unique                                   189                        189
# top     5b6a51a4-5c13-42b0-b885-8936c9cc36f3  2017-01-25T15:04:04-05:00
# freq                                      20                         20
#
#        Observation Type Observation Value
# count              1310              1147
# unique               31               459
# top         Body Height         1.0 mg/dL
# freq                159                45

# %% [markdown]
# diagnostic data

# %%
diagnostic = pd.read_csv('./output_csv/diagnostic_data.csv')

# %%
diagnostic[20:30]
# Out:
#                     Diagnostic Report ID Status        Diagnostic Name  \
# 20  18cb1577-3300-47b2-8d57-38f9cd8b950b  final  Basic Metabolic Panel
# 21  18cb1577-3300-47b2-8d57-38f9cd8b950b  final  Basic Metabolic Panel
# 22  18cb1577-3300-47b2-8d57-38f9cd8b950b  final  Basic Metabolic Panel
# 23  18cb1577-3300-47b2-8d57-38f9cd8b950b  final  Basic Metabolic Panel
# 24  18cb1577-3300-47b2-8d57-38f9cd8b950b  final  Basic Metabolic Panel
# 25  18cb1577-3300-47b2-8d57-38f9cd8b950b  final  Basic Metabolic Panel
# 26  18cb1577-3300-47b2-8d57-38f9cd8b950b  final  Basic Metabolic Panel
# 27  18cb1577-3300-47b2-8d57-38f9cd8b950b  final  Basic Metabolic Panel
# 28  d79b10af-0929-46a2-a880-494d4affbba8  final            Lipid Panel
# 29  d79b10af-0929-46a2-a880-494d4affbba8  final            Lipid Panel
#
#                               Patient ID  \
# 20  d0ed1873-9ac6-4c98-813e-86a041ce78c5
# 21  d0ed1873-9ac6-4c98-813e-86a041ce78c5
# 22  d0ed1873-9ac6-4c98-813e-86a041ce78c5
# 23  d0ed1873-9ac6-4c98-813e-86a041ce78c5
# e23fb9ad-56f4-4e34-8073-6c89277f03f8     4
# 0e356358-6f2d-453d-b1eb-1883f3255233     4
# 87a995d0-67b2-48b2-a489-0450ba43754d     4
# 98bfac77-82aa-4ffa-a63c-06f13e722550     4
# 61bc1b33-2041-4d0e-850e-96701198a43d     4
# f5b01614-f569-4e9e-b482-cc0231a7c20a     4
# ae0ab80e-1d3c-4c78-9ff5-1864cb415c0e     4
# 353bd039-42e0-4750-981c-50d594b67a4d     4
# 5948265c-890d-4b41-9b89-61b195cfa4c5     4
# d90f6271-c1ce-4d06-831e-060142761020     4
# 1ab08082-a652-4337-aaa0-57d2e024b7f2     4
# bb0f8e08-8947-41a9-8191-e5b237628070     4
# 935d423e-7a06-4fd2-94b0-24f9c1e0e3fa     4
# 9e21cf90-aa49-4f0e-85d0-a535c280ec06     4
# 2ee2bc32-9d5d-41f8-9b54-8b45749985c3     4
# ab8111af-0a2e-4dc4-8556-fd100f3b61b5     1
# dc68d226-b62b-45b8-baab-a1cc6d26427f     1
# d2ff93b8-0e15-495c-9f34-b35033023848     1
# e474dde0-32b2-404c-8622-bc008af313e4     1
# Name: count, dtype: int64

# %%
len(diagnostic['Encounter ID'].unique())
# Out:
# 69

# %%
diagnostic_to_merge = diagnostic[['Encounter ID','Diagnostic Report ID']]

# %%
diagnostic_to_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 524 entries, 0 to 523
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Encounter ID          524 non-null    object
#  1   Diagnostic Report ID  524 non-null    object
# dtypes: object(2)
# memory usage: 8.3+ KB

# %%
diagnostic_to_merge.head(10)
# Out:
#                            Encounter ID                  Diagnostic Report ID
# 0  e23fb9ad-56f4-4e34-8073-6c89277f03f8  a07a9a48-de2f-4b5a-896e-c44d56eeb3c0
# 1  e23fb9ad-56f4-4e34-8073-6c89277f03f8  a07a9a48-de2f-4b5a-896e-c44d56eeb3c0
# 2  e23fb9ad-56f4-4e34-8073-6c89277f03f8  a07a9a48-de2f-4b5a-896e-c44d56eeb3c0
# 3  e23fb9ad-56f4-4e34-8073-6c89277f03f8  a07a9a48-de2f-4b5a-896e-c44d56eeb3c0
# 4  0e41d495-029e-4338-8173-25e62f81a199  f74a3d92-b549-4a12-9e10-6a6d2204b59b
# 5  0e41d495-029e-4338-8173-25e62f81a199  f74a3d92-b549-4a12-9e10-6a6d2204b59b
# 6  0e41d495-029e-4338-8173-25e62f81a199  f74a3d92-b549-4a12-9e10-6a6d2204b59b
# 7  0e41d495-029e-4338-8173-25e62f81a199  f74a3d92-b549-4a12-9e10-6a6d2204b59b
# 8  0e41d495-029e-4338-8173-25e62f81a199  f74a3d92-b549-4a12-9e10-6a6d2204b59b
# 9  0e41d495-029e-4338-8173-25e62f81a199  f74a3d92-b549-4a12-9e10-6a6d2204b59b

# %%
diagnostic_to_merge_drop = diagnostic_to_merge.drop_duplicates(subset=['Diagnostic Report ID'])

# %%
diagnostic_to_merge_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89 entries, 0 to 520
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   
# 173  Hospital Lab  urn:uuid:4b31fec0-29a3-44d9-b24d-3a684c9ccbef
# 174  Hospital Lab  urn:uuid:d5643bea-fec0-454c-9330-e2dd671762d4
# 175  Hospital Lab  urn:uuid:e7093ab9-1f93-4085-8862-0139639a172e
# 176  Hospital Lab  urn:uuid:538f3066-f95d-41ad-8060-37cec0c2a744
# 177  Hospital Lab  urn:uuid:ce9c8708-0988-4512-9e8d-c05b26c19eeb
# 178  Hospital Lab  urn:uuid:d25b5cce-494b-4278-bca2-f0c32cdc5585
# 179  Hospital Lab  urn:uuid:934e6d18-678f-4aaf-8288-aa0314a4e3e2
# 180  Hospital Lab  urn:uuid:af144155-6ae5-4911-ad23-74d8eb7ac387
#
#                            result_display
# 169                               Glucose
# 170                         Urea Nitrogen
# 171                            Creatinine
# 172                               Calcium
# 173                                Sodium
# 174                             Potassium
# 175                              Chloride
# 176                        Carbon Dioxide
# 177                     Total Cholesterol
# 178                         Triglycerides
# 179   Low Density Lipoprotein Cholesterol
# 180  High Density Lipoprotein Cholesterol

# %% [markdown]
# explore join for this

# %%
test = pd.merge(result_df,diagnostic_to_merge_drop,how='left',on='Encounter ID')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1693 entries, 0 to 1692
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Observation ID         1693 non-null   object
#  1   Status                 1693 non-null   object
#  2   Patient ID             1693 non-null   object
#  3   Encounter ID           1693 non-null   object
#  4   Observation Date Time  1693 non-null   object
#  5   Observation Type       1693 non-null   object
#  6   Observation Value      1510 non-null   object
#  7   Diagnostic Report ID   1290 non-null   object
# dtypes: object(8)
# memory usage: 105.9+ KB

# %%
test.describe()
# Out:
#                               Observation ID Status  \
# count                                   1693   1693
# unique                                  1310      1
# top     7b321269-d21a-4181-bfb6-a03287c7d798  final
# freq                                       2   1693
#
#                                   Patient ID  \
# count                                   1693
# unique                                    34
# top     aa3973d9-b64f-4a36-8cb6-f2719080b52f
# freq                                     361
#
#                                 Encounter ID      Observation Date Time  \
# count                                   1693                       1693
# unique                                   189                        189
# top     9c6ee96e-445f-42b9-a711-d8acb2788bc3  2013-11-15T14:33:03-05:00
# freq                                      40                         40
#
#        Observation Type Observation Value  \
# count              1693              1510
# unique               31               459
# top         Body Weight         1.0 mg/dL
# freq                179                65
#
#                         Diagnostic Report ID
# count                                   1290
# unique                                    89
# top     7e510599-af63-4cba-bf6b-3799c65c7854
# freq                                      20

# %%
test[test['Diagnostic Report ID'].isna()]
# Out:
#                             Observation ID Status  \
# 0     166ab0d5-66bc-40fc-922b-2896cca3b0d9  final
# 1     77bda9d9-e213-471f-9dec-9b5b03ff38b8  final
# 2     322e6431-9a54-4e5f-9904-9ad4d5a3253b  final
# 3     7d2b3ee3-1190-45fc-a876-df6b171c5c0b  final
# 4     3fd3dd3d-4382-4ae0-b1cc-7e5c9220da22  final
# ...                                    ...    ...
# 1688  35dc154b-f576-4f61-aedc-1ce50bbea065  final
# 1689  1e9a385e-e673-4dc0-9a35-24413d419e6a  final
# 1690  af37a792-b514-422b-b739-24034ff4a77a  final
# 1691  9bb8bf87-aaef-417f-81e6-9060ec081be6  final
# 1692  26214499-2d89-4f13-9b41-6aef9e376b5a  final
#
#                                 Patient ID  \
# 0     65d12976-9588-4cfa-a795-216302a2ece9
# 1     65d12976-9588-4cfa-a795-216302a2ece9
# 2     65d12976-9588-4cfa-a795-216302a2ece9
# 3     65d12976-9588-4cfa-a795-216302a2ece9
# 4     65d12976-9588-4cfa-a795-216302a2ece9
# ...                                    ...
# 1688  a5399e95-981c-4a78-8019-873662fc7901
# 1689  a5399e95-981c-4a78-8019-873662fc7901
# 1690  a5399e95-981c-4a78-8019-873662fc7901
# 1691  a5399e95-981c-4a78-8019-873662fc7901
# 1692  a5399e95-981c-4a78-8019-873662fc7901
#
#                               Encounter ID      Observation Date Time  \
# 0     a3e3bd43-ef3c-48fd-9851-5302d1aa84c6  2010-07-31T13:21:25-04:00
# 1     7e969f44-f034-48c1-82c9-0fcf4b24e20c  2010-09-15T10:46:26-04:00
# 2     a5e0fd67-d09f-4861-a58f-5726d81faafc  2010-11-14T10:21:49-05:00
# 3     a5e0fd67-d09f-4861-a58f-5726d81faafc  2010-11-14T10:21:49-05:00
# 4     a5e0fd67-d09f-4861-a58f-5726d81faafc  2010-11-14T10:21:49-05:00
# ...                                    ...                        ...
# 1688  9e802e2c-77ad-401f-97e9-bb91f646b9d7  2016-10-26T05:38:21-04:00
# 1689  9e802e2c-77ad-401f-97e9-bb91f646b9d7  2016-10-26T05:38:21-04:00
# 1690  9e802e2c-77ad-401f-97e9-bb91f646b9d7  2016-10-26T05:38:21-04:00
# 1691  9e802e2c-77ad-401f-97e9-bb91f646b9d7  2016-10-26T05:38:21-04:00
# 1692  9e802e2c-77ad-401f-97e9-bb91f646b9d7  2016-10-26T05:38:21-04:00
#
#                           Observation Type     Observation Value  \
# 0                         Oral temperature              37.3 Cel
# 1                         Oral temperature              37.0 Cel
# 2                              Body Height              132.2 cm
# 3                              Body Weight               36.1 kg
# 4                          Body Mass Index            20.6 kg/m2
# ...                                    ...                   ...
# 1688                           Body Height              180.1 cm
# 1689                           Body Weight               85.6 kg
# 1690                       Body Mass Index            26.4 kg/m2
# 1691                        Blood Pressure                   NaN
# 1692  Estimated Glomerular Filtration Rate  0.0 mL/min/{1.73_m2}
#
#      Diagnostic Report ID
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1688                  NaN
# 1689                  NaN
# 1690                  NaN
# 1691                  NaN
# 1692                  NaN
#
# [403 rows x 8 columns]

# %%
test[test['Observation ID'].isna()]
# Out:
# Empty DataFrame
# Columns: [Observation ID, Status, Patient ID, Encounter ID, Observation Date Time, Observation Type, Observation Value, Diagnostic Report ID]
# Index: []

# %%
test[test['Observation ID'].duplicated()]
# Out:
#                             Observation ID Status  \
# 37    95d2ce05-8d62-41eb-a655-52fcd5c71b56  final
# 39    98944af2-78ce-41cb-84f0-19ea2b119a88  final
# 41    3505cda9-c446-48f6-8b53-309511a5d3bd  final
# 43    4867ff78-ff2c-465b-b16b-42563729f9b3  final
# 45    f8673fda-cef1-4f76-a77f-953f7f45486a  final
# ...                                    ...    ...
# 1684  e4e56824-be5d-40f5-800e-052841b16eea  final
# 1686  b7b2e34e-b5a2-4879-9305-e20d9df9d6f5  final
# 1690  74bc393d-eb75-42f9-8132-45ccc3165b60
# 1692  74bc393d-eb75-42f9-8132-45ccc3165b60
#
# [383 rows x 8 columns]

# %%
test[test['Observation ID'] == '95d2ce05-8d62-41eb-a655-52fcd5c71b56']
# Out:
#                           Observation ID Status  \
# 36  95d2ce05-8d62-41eb-a655-52fcd5c71b56  final
# 37  95d2ce05-8d62-41eb-a655-52fcd5c71b56  final
#
#                               Patient ID  \
# 36  bb357dc7-2f8a-444e-ba57-8291b6f18bf0
# 37  bb357dc7-2f8a-444e-ba57-8291b6f18bf0
#
#                             Encounter ID      Observation Date Time  \
# 36  aa76d5b2-8587-4dae-b5f9-487ac3a89308  2010-07-26T02:41:32-04:00
# 37  aa76d5b2-8587-4dae-b5f9-487ac3a89308  2010-07-26T02:41:32-04:00
#
#                             Observation Type Observation Value  \
# 36  Hemoglobin A1c/Hemoglobin.total in Blood             6.1 %
# 37  Hemoglobin A1c/Hemoglobin.total in Blood             6.1 %
#
#                     Diagnostic Report ID
# 36  fd75cd83-df55-45a0-9ff6-34ebf82e2864
# 37  88e262b5-53fd-49a7-8057-a8a301757594

# %% [markdown]
# ## Observation Data Extraction

# %%
import pandas as pd
import glob

# %%
def extract_observation_data(root_directory_path):
    file_paths = glob.glob(f"{root_directory_path}*.json")
    dfs = [pd.read_json(file_path) for file_path in file_paths]
    combined_df = pd.concat(dfs, ignore_index=True)
    entries = pd.json_normalize(combined_df['entry'])

    observation_data = entries[entries['resource.resourceType'] == 'Observation']
    observation_data.reset_index(drop=True,inplace=True)

    observation_id = observation_data.get('resource.id',None)
    observation_status = observation_data.get('resource.status',None)
    #observation type
    observation_type_raw = observation_data.get('resource.code.coding',None)
    if not observation_type_raw is None:
        observation_type = pd.json_normalize(observation_type_raw.explode()).get('display',None)
    else:
        observation_type = None
    #observation value
    observation_value = observation_data.get('resource.valueQuantity.value',None).apply(lambda x: round(x,1))
    observation_unit = observation_data.get('resource.valueQuantity.unit',None)
    if not observation_value is None:
        observation_value_unit = observation_value.astype('str').str.cat(observation_unit,sep=' ')
    else:
        observation_value_unit = None
    #observatoin date time
    observation_date_time = observation_data.get('resource.effectiveDateTime',None)
    observation_encounter_id = observation_data['resource.encounter.reference'].str.replace('urn:uuid:','')
    observation_patient_id = observation_data['resource.subject.reference'].str.replace('urn:uuid:','')

    result_df = pd.DataFrame({
    'Observation ID':observation_id,
    'Status':observation_status,
    'Patient ID':observation_patient_id,
    'Encounter ID':observation_encounter_id,
    'Observation Date Time':observation_date_time,
    'Observation Type':observation_type,
    'Observation Value':observation_value_unit
    })

    diagnostic = pd.read_csv('./output_csv/diagnostic_data.csv')
    diagnostic_to_merge = diagnostic[['Encounter ID','Diagnostic Report ID']]
    diagnostic_to_merge_drop = diagnostic_to_merge.drop_duplicates(subset=['Diagnostic Report ID'])
    final_df = pd.merge(result_df,diagnostic_to_merge_drop,how='left',on='Encounter ID')

    final_df.to_csv('./output_csv/observatoin_data.csv',index=False)

# %%
extract_observation_data('./health_data/healthcare-datasets/')

# %% [markdown]
# # Process Observation data

# %%
import pandas as pd
observation = pd.read_csv('./output_csv/observatoin_data.csv')

# %%
observation.head()
# Out:
#                          Observation ID Status  \
# 0  166ab0d5-66bc-40fc-922b-2896cca3b0d9  final
# 1  77bda9d9-e213-471f-9dec-9b5b03ff38b8  final
# 2  322e6431-9a54-4e5f-9904-9ad4d5a3253b  final
# 3  7d2b3ee3-1190-45fc-a876-df6b171c5c0b  final
# 4  3fd3dd3d-4382-4ae0-b1cc-7e5c9220da22  final
#
#                              Patient ID                          Encounter ID  \
# 0  65d12976-9588-4cfa-a795-216302a2ece9  a3e3bd43-ef3c-48fd-9851-5302d1aa84c6
# 1  65d12976-9588-4cfa-a795-216302a2ece9  7e969f44-f034-48c1-82c9-0fcf4b24e20c
# 2  65d12976-9588-4cfa-a795-216302a2ece9  a5e0fd67-d09f-4861-a58f-5726d81faafc
# 3  65d12976-9588-4cfa-a795-216302a2ece9  a5e0fd67-d09f-4861-a58f-5726d81faafc
# 4  65d12976-9588-4cfa-a795-216302a2ece9  a5e0fd67-d09f-4861-a58f-5726d81faafc
#
#        Observation Date Time  Observation Type Observation Value  \
# 0  2010-07-31T13:21:25-04:00  Oral temperature          37.3 Cel
# 1  2010-09-15T10:46:26-04:00  Oral temperature          37.0 Cel
# 2  2010-11-14T10:21:49-05:00       Body Height          132.2 cm
# 3  2010-11-14T10:21:49-05:00       Body Weight           36.1 kg
# 4  2010-11-14T10:21:49-05:00   Body Mass Index        20.6 kg/m2
#
#   Diagnostic Report ID
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
observation[observation['Diagnostic Report ID'].isna()].describe()
# Out:
#                               Observation ID Status  \
# count                                    403    403
# unique                                   403      1
# top     166ab0d5-66bc-40fc-922b-2896cca3b0d9  final
# freq                                       1    403
#
#                                   Patient ID  \
# count                                    403
# unique                                    24
# top     2f3f9a7e-8142-40c8-8c4a-b58bc815b48d
# freq                                      39
#
#                                 Encounter ID      Observation Date Time  \
# count                                    403                        403
# unique                                   120                        120
# top     8980d9a8-66ee-4163-8910-35ba6584b556  2016-06-03T10:03:58-04:00
# freq                                       6                          6
#
#        Observation Type Observation Value Diagnostic Report ID
# count               403               309                    0
# unique               15               184                    0
# top         Body Height          38.0 Cel                  NaN
# freq                 94                10                  NaN

# %%
observation[observation['Diagnostic Report ID'].notna()].describe()
# Out:
#                               Observation ID Status  \
# count                                   1290   1290
# unique                                   907      1
# top     9d9b8fe9-f080-435e-a36c-2c12735b21bc  final
# freq                                       2   1290
#
#                                   Patient ID  \
# count                                   1290
# unique                                    23
# top     aa3973d9-b64f-4a36-8cb6-f2719080b52f
# freq                                     360
#
#                                 Encounter ID      Observation Date Time  \
# count                                   1290                       1290
# unique                                    69                         69
# top     b8edeb00-4f36-47b5-9b99-12a05ad57691  2014-09-11T11:29:25-04:00
# freq                                      40                         40
#
#                                 Observation Type Observation Value  \
# count                                       1290              1201
# unique                                        22               313
# top     Hemoglobin A1c/Hemoglobin.total in Blood         1.0 mg/dL
# freq                                         130                65
#
#                         Diagnostic Report ID
# count                                   1290
# unique                                    89
# top     7e510599-af63-4cba-bf6b-3799c65c7854
# freq                                      20
